# %% [markdown]
# <h1>DAY 1 OF ML</h1>

# %% [markdown]
# <h1>Codes 1</h1>

# %%
import pandas as pd

# %%
df=pd.read_csv("Daily_Cal_Req.csv")
df.head(10)
# Out:
#     Age  Gender  Height_cm  Weight_kg Activity_Level  Sleep_Hours  \
# 0  58.0    Male      151.0       80.0          Light          5.6
# 1  46.0  Female      150.0       65.0         Active          6.2
# 2  53.0  Female      190.0       91.0    Very Active          5.5
# 3  60.0  Female      154.0       66.0    Very Active          8.1
# 4  35.0    Male      163.0       85.0          Light          7.8
# 5  26.0  Female      155.0       51.0      Sedentary          5.3
# 6   NaN     NaN      171.0       59.0       Moderate          6.7
# 7  40.0    Male      188.0       86.0         Active          7.2
# 8  48.0    Male      166.0       99.0          Light          9.1
# 9   NaN     NaN      171.0       73.0      Sedentary          4.9
#
#    Water_Intake_L      Goal Diet_Type  Daily_Calorie_Requirement
# 0             3.6      Gain       Veg                       2306
# 1             1.5  Maintain       Veg                       2064
# 2             1.2      Gain   Non-Veg                       3476
# 3             1.6      Gain     Vegan                       2207
# 4             2.4      Gain      Jain                       2636
# 5             1.6      Gain      Jain                       1725
# 6             2.6      Gain     Vegan                       2219
# 7             4.3  Maintain   Non-Veg                       3278
# 8             3.6      Gain       Veg                       2765
# 9             3.2      Lose       Veg                       1666

# %%
df.isnull().sum()
# Out:
# Age                          25
# Gender                       25
# Height_cm                     0
# Weight_kg                     0
# Activity_Level                0
# Sleep_Hours                   0
# Water_Intake_L                0
# Goal                          0
# Diet_Type                     0
# Daily_Calorie_Requirement     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 50

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Height_cm', 'Weight_kg', 'Activity_Level',
#        'Sleep_Hours', 'Water_Intake_L', 'Goal', 'Diet_Type',
#        'Daily_Calorie_Requirement'],
#       dtype='object')

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      131
# Female     94
# Name: count, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# Age
# 40.0    20
# 53.0    10
# 30.0    10
# 59.0     9
# 38.0     8
# 48.0     8
# 34.0     8
# 51.0     7
# 33.0     7
# 21.0     7
# 27.0     6
# 46.0     6
# 39.0     6
# 57.0     6
# 54.0     6
# 32.0     5
# 41.0     5
# 37.0     5
# 19.0     5
# 52.0     5
# 60.0     5
# 47.0     5
# 43.0     5
# 20.0     4
# 55.0     4
# 42.0     4
# 25.0     4
# 24.0     4
# 18.0     4
# 56.0     4
# 36.0     4
# 58.0     3
# 22.0     3
# 23.0     3
# 49.0     3
# 26.0     3
# 35.0     3
# 44.0     2
# 50.0     2
# 28.0     2
# 45.0     2
# 29.0     2
# 31.0     1
# Name: count, dtype: int64

# %%
df["Height_cm"].value_counts()
# Out:
# Height_cm
# 171.0    25
# 165.0    13
# 190.0    11
# 182.0    10
# 153.0     8
# 155.0     8
# 188.0     8
# 179.0     7
# 176.0     7
# 160.0     7
# 167.0     7
# 175.0     7
# 162.0     7
# 156.0     7
# 180.0     6
# 158.0     6
# 178.0     6
# 177.0     6
# 185.0     6
# 157.0     6
# 174.0     5
# 150.0     5
# 184.0     5
# 172.0     5
# 168.0     4
# 183.0     4
# 187.0     4
# 151.0     4
# 159.0     4
# 189.0     4
# 161.0     4
# 173.0     4
# 181.0     4
# 166.0     4
# 163.0     4
# 154.0     4
# 169.0     4
# 170.0     3
# 164.0     3
# 186.0     2
# 152.0     2
# Name: count, dtype: int64

# %%
df["Weight_kg"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       80.0
# 1       65.0
# 2       91.0
# 3       66.0
# 4       85.0
#        ...
# 245     85.0
# 246     81.0
# 247     79.0
# 248    100.0
# 249     57.0
# Name: Weight_kg, Length: 250, dtype: float64>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
df["Gender"].value_counts().plot(kind="bar")
plt.tight_layout()
plt.show()
df["Gender"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
from IPython.display import Image
Image(filename="//home//kanhaiya-bhatt//Downloads//image (10).png")

# %%
# !pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.12/site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in ./anaconda3/lib/python3.12/site-packages (from missingno) (3.9.2)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.12/site-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in ./anaconda3/lib/python3.12/site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=8 in ./anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in ./anaconda3/lib/python3.12/site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.12/site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./anaconda3/lib/python3.12/site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2

# %%
import missingno as ms
ms.matrix(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ms.bar(df,color="red")
plt.show()

# %%
df_new=df.dropna()
df_new.shape
# Out:
# (225, 10)

# %%
df_new=df.dropna(axis=1)
df_new.shape
# Out:
# (250, 8)

# %%
df_new.columns
# Out:
# Index(['Height_cm', 'Weight_kg', 'Activity_Level', 'Sleep_Hours',
#        'Water_Intake_L', 'Goal', 'Diet_Type', 'Daily_Calorie_Requirement'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Height_cm', 'Weight_kg', 'Activity_Level',
#        'Sleep_Hours', 'Water_Intake_L', 'Goal', 'Diet_Type',
#        'Daily_Calorie_Requirement'],
#       dtype='object')

# %%
df.fillna({"Age":18,"Gender":"Male"},inplace=True)
df.isna().sum()
# Out:
# Age                          0
# Gender                       0
# Height_cm                    0
# Weight_kg                    0
# Activity_Level               0
# Sleep_Hours                  0
# Water_Intake_L               0
# Goal                         0
# Diet_Type                    0
# Daily_Calorie_Requirement    0
# dtype: int64

# %%
df=pd.read_csv("Daily_Cal_Req.csv")

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())
df["Age"].isnull().sum()
# Out:
# 0

# %%
df["Gender"]=df["Gender"].fillna(df["Gender"].mode()[0])
df["Gender"].isnull().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Age  Height_cm   Weight_kg  Sleep_Hours  Water_Intake_L  \
# count  250.000000  250.00000  250.000000   250.000000      250.000000
# mean    40.060000  170.50800   78.168000     7.158000        2.775200
# std     11.388027   11.44438   18.307606     1.424272        0.965564
# min     18.000000  150.00000   45.000000     4.500000        1.000000
# 25%     32.250000  161.00000   64.000000     6.000000        2.000000
# 50%     40.000000  171.00000   81.000000     7.200000        2.700000
# 75%     49.000000  180.00000   91.000000     8.475000        3.600000
# max     60.000000  190.00000  110.000000     9.500000        4.500000
#
#        Daily_Calorie_Requirement
# count                  250.00000
# mean                  2462.46000
# std                    553.84209
# min                   1167.00000
# 25%                   2088.50000
# 50%                   2404.00000
# 75%                   2823.50000
# max                   4107.00000

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm")
plt.show()

# %%
import plotly.express as px
fig=px.histogram(df,x="Age",nbins=10,color="Gender")
fig.update_layout(bargap=0.05,
                  width=500,
                  height=500)
fig.show()

# %%
fig=px.scatter(df,x="Height_cm",y="Weight_kg",
               size="Daily_Calorie_Requirement",
               color="Activity_Level",
               hover_data="Age")
fig.show()

# %%
fig=px.treemap(
df, 
path=["Goal","Activity_Level","Diet_Type"]
)
fig.update_traces(
    textinfo="label+value")
fig.show()

# %%
fig=px.sunburst(
df, 
path=["Goal","Diet_Type"]
)

fig.show()
